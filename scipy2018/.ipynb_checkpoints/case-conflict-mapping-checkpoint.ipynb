# %%
# %matplotlib inline

import pandas as pd
import geopandas
import matplotlib.pyplot as plt

# %% [markdown]
# # Case study - Conflict mapping: mining sites in eastern DR Congo
#
# In this case study, we will explore a dataset on artisanal mining sites located in eastern DR Congo.
#
# **Note**: this tutorial is meant as a hands-on session, and most code examples are provided as exercises to be filled in. I highly recommend actually trying to do this yourself, but if you want to follow the solved tutorial, you can find this in the `_solved` directory.
#
# ---
#
# #### Background
#
# [IPIS](http://ipisresearch.be/), the International Peace Information Service, manages a database on mining site visits in eastern DR Congo: http://ipisresearch.be/home/conflict-mapping/maps/open-data/
#
# Since  2009, IPIS has visited artisanal mining sites in the region during various data collection campaigns. As part of these campaigns, surveyor teams visit mining sites in the field, meet with miners and complete predefined questionnaires. These contain questions about the mining site, the minerals mined at the site and the armed groups possibly present at the site.
#
# Some additional links:
#
# * Tutorial on the same data using R from IPIS (but without geospatial aspect): http://ipisresearch.be/home/conflict-mapping/maps/open-data/open-data-tutorial/
# * Interactive web app using the same data: http://www.ipisresearch.be/mapping/webmapping/drcongo/v5/

# %% [markdown]
# ## 1. Importing and exploring the data

# %% [markdown]
# ### The mining site visit data
#
# IPIS provides a WFS server to access the data. We can send a query to this server to download the data, and load the result into a geopandas GeoDataFrame:

# %%
import requests
import json

wfs_url = "http://geo.ipisresearch.be/geoserver/public/ows"
params = dict(service='WFS', version='1.0.0', request='GetFeature',
              typeName='public:cod_mines_curated_all_opendata_p_ipis', outputFormat='json')

r = requests.get(wfs_url, params=params)
data_features = json.loads(r.content.decode('UTF-8'))
data_visits = geopandas.GeoDataFrame.from_features(data_features)

# %%
data_features
# Out:
# {'type': 'FeatureCollection',
#  'totalFeatures': 5007,
#  'features': [{'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a25',
#    'geometry': {'type': 'Point', 'coordinates': [28.71258, 0.33188]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 1,
#     'cid': 1,
#     'id': 130,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00191',
#     'name': 'Eohe',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.71258,
#     'latitude': 0.33188,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Lubero',
#     'collectivite': 'Bapere',
#     'groupement': 'Baredje',
#     'village': 'Maendeleo',
#     'workers_numb': 300,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a26',
#    'geometry': {'type': 'Point', 'coordinates': [28.69916, 0.32153]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 2,
#     'cid': 2,
#     'id': 101,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00192',
#     'name': 'Eita',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.69916,
#     'latitude': 0.32153,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Lubero',
#     'collectivite': 'Bapere',
#     'groupement': 'Baredje',
#     'village': 'Tembe',
#     'workers_numb': 110,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a27',
#    'geometry': {'type': 'Point', 'coordinates': [28.1851423, 0.54499175]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 3,
#     'cid': 3,
#     'id': 166,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00242',
#     'name': 'Mungu Iko',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.1851422995,
#     'latitude': 0.5449917486,
#     'location_origin': 'GPS (Approximation)',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Lubero',
#     'collectivite': 'Bapere',
#     'groupement': 'Bapaitumba',
#     'village': 'Ehoto',
#     'workers_numb': None,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Coltan',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': 'Maï-Maï Simba',
#     'type_armed_group2': 'Groupe armé local',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a28',
#    'geometry': {'type': 'Point', 'coordinates': [28.884528, -0.352529]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 4,
#     'cid': 4,
#     'id': 163,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00260',
#     'name': 'Kiviri/Tayna',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.884528,
#     'latitude': -0.352529,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Lubero',
#     'collectivite': 'Bamate',
#     'groupement': 'Luenge',
#     'village': 'Vunyakavulivwa',
#     'workers_numb': None,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Diamant',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FDLR',
#     'type_armed_group1': 'Groupe armé étranger',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': 'Maï-Maï',
#     'type_armed_group2': 'Groupe armé local',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a29',
#    'geometry': {'type': 'Point', 'coordinates': [28.903945, -0.036707]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 5,
#     'cid': 5,
#     'id': 172,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00272',
#     'name': 'Makanga',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.903945,
#     'latitude': -0.036707,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Lubero',
#     'collectivite': 'Batangi',
#     'groupement': 'Musindi',
#     'village': 'Ngohi',
#     'workers_numb': None,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Diamant',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FDLR',
#     'type_armed_group1': 'Groupe armé étranger',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2a',
#    'geometry': {'type': 'Point', 'coordinates': [29.422085, 0.88749167]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 6,
#     'cid': 6,
#     'id': 70,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00286',
#     'name': 'Kasongo',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 29.422085,
#     'latitude': 0.8874916666666667,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Beni',
#     'collectivite': 'Beni-Mbau',
#     'groupement': 'Batangi-Mbau',
#     'village': 'Mamove',
#     'workers_numb': 50,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2b',
#    'geometry': {'type': 'Point', 'coordinates': [29.24183, 0.595655]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 7,
#     'cid': 7,
#     'id': 30,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00288',
#     'name': 'Mununze',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 29.24183,
#     'latitude': 0.595655,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Beni',
#     'collectivite': 'Beni-Mbau',
#     'groupement': 'Baswagha-Madiwe',
#     'village': 'Mununze',
#     'workers_numb': 20,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2c',
#    'geometry': {'type': 'Point', 'coordinates': [29.09466, 0.459223]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 8,
#     'cid': 8,
#     'id': 131,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00290',
#     'name': 'Kiboto',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 29.09466,
#     'latitude': 0.459223,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Beni',
#     'collectivite': 'Beni-Mbau',
#     'groupement': 'Baswagha-Madiwe',
#     'village': 'Cantine/Aloya',
#     'workers_numb': 300,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2d',
#    'geometry': {'type': 'Point', 'coordinates': [28.884336, -1.696243]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 9,
#     'cid': 9,
#     'id': 38,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00307',
#     'name': 'Ruzirantaka (rivière)',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.884336,
#     'latitude': -1.696243,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Muvunyi-Shanga',
#     'village': 'Ruzirantaka',
#     'workers_numb': 27,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Tourmaline',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2e',
#    'geometry': {'type': 'Point', 'coordinates': [28.893558, -1.584475]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 10,
#     'cid': 10,
#     'id': 148,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00309',
#     'name': 'D3 Bibatama',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.893558,
#     'latitude': -1.584475,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Muvunyi-Karuba',
#     'village': 'Rugeshi/Humule',
#     'workers_numb': 1150,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Coltan',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a2f',
#    'geometry': {'type': 'Point', 'coordinates': [28.882969, -1.570912]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 11,
#     'cid': 11,
#     'id': 144,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00311',
#     'name': 'D4 Gakombe',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.882969,
#     'latitude': -1.570912,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Matanda',
#     'village': 'Karambayiro/Luhundje',
#     'workers_numb': 700,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Coltan',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a30',
#    'geometry': {'type': 'Point', 'coordinates': [28.887091, -1.56652]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 12,
#     'cid': 12,
#     'id': 68,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00312',
#     'name': 'Luwowo/Gasasa',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.887091,
#     'latitude': -1.56652,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Matanda',
#     'village': 'Luwowo/Luhundje',
#     'workers_numb': 50,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Coltan',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Cassitérite',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a31',
#    'geometry': {'type': 'Point', 'coordinates': [28.888861, -1.578194]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 13,
#     'cid': 13,
#     'id': 143,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00318',
#     'name': 'D2 Bibatama',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.888861,
#     'latitude': -1.578194,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Karuba',
#     'village': 'Humule',
#     'workers_numb': 612,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Coltan',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a32',
#    'geometry': {'type': 'Point', 'coordinates': [28.90377778, -1.55738889]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 14,
#     'cid': 14,
#     'id': 58,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00319',
#     'name': 'Koyi',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.9037777778,
#     'latitude': -1.5573888889,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Masisi',
#     'collectivite': 'Bahunde',
#     'groupement': 'Matanda',
#     'village': 'Luhundje',
#     'workers_numb': 45,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Coltan',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a33',
#    'geometry': {'type': 'Point', 'coordinates': [28.29888, -1.10362]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 15,
#     'cid': 15,
#     'id': 51,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00377',
#     'name': 'Mironge',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 28.29888,
#     'latitude': -1.10362,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Ihana',
#     'village': 'Banamutabira',
#     'workers_numb': 40,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FDLR',
#     'type_armed_group1': 'Groupe armé étranger',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a34',
#    'geometry': {'type': 'Point', 'coordinates': [27.876402, -1.126632]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 16,
#     'cid': 16,
#     'id': 78,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00381',
#     'name': 'Shempika',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.876402,
#     'latitude': -1.126632,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bakondjo',
#     'workers_numb': 54,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a35',
#    'geometry': {'type': 'Point', 'coordinates': [27.860538, -1.094217]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 17,
#     'cid': 17,
#     'id': 132,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00382',
#     'name': 'Omate',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.860538,
#     'latitude': -1.094217,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bakondjo',
#     'workers_numb': 330,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a36',
#    'geometry': {'type': 'Point', 'coordinates': [27.85974, -1.081251]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 18,
#     'cid': 18,
#     'id': 10,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00383',
#     'name': 'Tokobika',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.85974,
#     'latitude': -1.081251,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bakondjo',
#     'workers_numb': 9,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Diamant',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a37',
#    'geometry': {'type': 'Point', 'coordinates': [27.868276, -1.071529]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 19,
#     'cid': 19,
#     'id': 206,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00384',
#     'name': 'Mafilo',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.868276,
#     'latitude': -1.071529,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bakondjo',
#     'workers_numb': None,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': None,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a38',
#    'geometry': {'type': 'Point', 'coordinates': [27.798437, -1.024498]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 20,
#     'cid': 20,
#     'id': 113,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00392',
#     'name': 'Angoa',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.798437,
#     'latitude': -1.024498,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Wassa',
#     'village': 'Banesa',
#     'workers_numb': 192,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Diamant',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': None,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Pas de données sur les ingérences',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3a39',
#    'geometry': {'type': 'Point', 'coordinates': [27.79815, -1.021475]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 21,
#     'cid': 21,
#     'id': 50,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - 2009',
#     'pcode': 'codmine00393',
#     'name': 'Kabombo',
#     'visit_date': '2009-01-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.79815,
#     'latitude': -1.021475,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Banesa',
#     'workers_numb': 39,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': None,
# ...
#     'province': 'Ituri',
#     'province_old': 'orientale',
#     'territoire': 'Mambasa',
#     'collectivite': 'Mambasa',
#     'groupement': 'Nyangwe',
#     'village': 'Saio',
#     'workers_numb': 100,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': 'Mambasa',
#     'final_destination_mineral1': 'Butembo',
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': 0,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e07',
#    'geometry': {'type': 'Point', 'coordinates': [26.37880556, -2.73586111]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 995,
#     'cid': 218,
#     'id': 218,
#     'source': 'BGR',
#     'project': 'Qualification status',
#     'pcode': 'codmine01101',
#     'name': 'Mambwe',
#     'visit_date': '2013-08-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 26.3788055556,
#     'latitude': -2.7358611111,
#     'location_origin': 'GPS',
#     'province': 'Maniema',
#     'province_old': 'Maniema',
#     'territoire': 'Pangi',
#     'collectivite': 'Beia',
#     'groupement': None,
#     'village': 'Mambwe',
#     'workers_numb': 60,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': 0,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': 'SAESSCAM',
#     'state_service2': 'Division des mines',
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': 'Vert',
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e08',
#    'geometry': {'type': 'Point', 'coordinates': [26.93461111, -2.43016667]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 996,
#     'cid': 224,
#     'id': 224,
#     'source': 'BGR',
#     'project': 'Qualification status',
#     'pcode': 'codmine01107',
#     'name': 'Binantwane',
#     'visit_date': '2013-08-01Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 26.9346111111,
#     'latitude': -2.4301666667,
#     'location_origin': 'GPS',
#     'province': 'Maniema',
#     'province_old': 'Maniema',
#     'territoire': 'Pangi',
#     'collectivite': 'Beia',
#     'groupement': None,
#     'village': 'Binantwane',
#     'workers_numb': 90,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': 0,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': 'SAESSCAM',
#     'state_service2': 'Division des mines',
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': 'Vert',
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e09',
#    'geometry': {'type': 'Point', 'coordinates': [26.24708333, -2.53919444]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 997,
#     'cid': 79,
#     'id': 79,
#     'source': 'BGR',
#     'project': 'Qualification status',
#     'pcode': 'codmine00623',
#     'name': 'Chamabondo',
#     'visit_date': '2013-08-21Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 26.2470833333,
#     'latitude': -2.5391944444,
#     'location_origin': 'GPS',
#     'province': 'Maniema',
#     'province_old': 'Maniema',
#     'territoire': 'Kailo',
#     'collectivite': 'Ambwe',
#     'groupement': 'Mwene Sud',
#     'village': 'Lonyoma',
#     'workers_numb': 300,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': 'Wolframite',
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': 0,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': 'SAESSCAM',
#     'state_service2': 'Division des mines',
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': 'Vert',
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e0a',
#    'geometry': {'type': 'Point', 'coordinates': [26.24286111, -2.50547222]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 998,
#     'cid': 207,
#     'id': 207,
#     'source': 'BGR',
#     'project': 'Qualification status',
#     'pcode': 'codmine01090',
#     'name': 'Tokomeka',
#     'visit_date': '2013-08-21Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 26.2428611111,
#     'latitude': -2.5054722222,
#     'location_origin': 'GPS',
#     'province': 'Maniema',
#     'province_old': 'Maniema',
#     'territoire': 'Kailo',
#     'collectivite': 'Ambwe',
#     'groupement': None,
#     'village': 'Bukandju',
#     'workers_numb': 28,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 1,
#     'is_gold_mine': 0,
#     'mineral1': 'Cassitérite',
#     'selling_points_mineral1': None,
#     'final_destination_mineral1': None,
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 0,
#     'interference': 0,
#     'armed_group1': None,
#     'type_armed_group1': '0',
#     'frequency_armed_group1': None,
#     'taxation_armed_group1': None,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': None,
#     'buying_minerals_armed_group1': None,
#     'digging_armed_group1': None,
#     'forced_labour_armed_group1': None,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': 'SAESSCAM',
#     'state_service2': 'Division des mines',
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': 'Vert',
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e0b',
#    'geometry': {'type': 'Point', 'coordinates': [27.880425, -1.212935]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 999,
#     'cid': 913,
#     'id': 362,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - PROMINES MoFA 2013-2014',
#     'pcode': 'codmine00379',
#     'name': 'Eliba',
#     'visit_date': '2013-08-22Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.880425,
#     'latitude': -1.212935,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bakondjo',
#     'workers_numb': 79,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': 'Ndjingala, Mubi, Walikale',
#     'final_destination_mineral1': 'Goma, Bukavu',
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': 1,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Éléments indisciplinés',
#     'frequency_armed_group1': 'Permanente',
#     'taxation_armed_group1': 1,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': 0,
#     'buying_minerals_armed_group1': 0,
#     'digging_armed_group1': 0,
#     'forced_labour_armed_group1': 0,
#     'pillaging_armed_group1': None,
#     'armed_group2': None,
#     'type_armed_group2': '0',
#     'frequency_armed_group2': None,
#     'taxation_armed_group2': None,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': None,
#     'buying_minerals_armed_group2': None,
#     'digging_armed_group2': None,
#     'forced_labour_armed_group2': None,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   {'type': 'Feature',
#    'id': 'cod_mines_curated_all_opendata_p_ipis.fid--41d8f413_17984c96dbc_3e0c',
#    'geometry': {'type': 'Point', 'coordinates': [27.88107, -1.174915]},
#    'geometry_name': 'geom',
#    'properties': {'vid': 1000,
#     'cid': 914,
#     'id': 363,
#     'source': 'IPIS - Ministère des Mines',
#     'project': 'IPIS - PROMINES MoFA 2013-2014',
#     'pcode': 'codmine00380',
#     'name': 'Nyaferenge',
#     'visit_date': '2013-08-22Z',
#     'visit_onsite': 1,
#     'visit_onsite_novisitreason': None,
#     'longitude': 27.88107,
#     'latitude': -1.174915,
#     'location_origin': 'GPS',
#     'province': 'Nord-Kivu',
#     'province_old': 'Nord-Kivu',
#     'territoire': 'Walikale',
#     'collectivite': 'Wanianga',
#     'groupement': 'Utunda',
#     'village': 'Bilobilo',
#     'workers_numb': 132,
#     'access_dry': None,
#     'access_wet': None,
#     'is_3t_mine': 0,
#     'is_gold_mine': 1,
#     'mineral1': 'Or',
#     'selling_points_mineral1': 'Ndjingala, Mubi, Walikale',
#     'final_destination_mineral1': 'Goma, Bukavu, Kisangani',
#     'mineral2': None,
#     'selling_points_mineral2': None,
#     'final_destination_mineral2': None,
#     'mineral3': None,
#     'selling_points_mineral3': None,
#     'final_destination_mineral3': None,
#     'mercury': None,
#     'presence': 1,
#     'interference': 1,
#     'armed_group1': 'FARDC',
#     'type_armed_group1': 'FARDC - Éléments indisciplinés',
#     'frequency_armed_group1': 'Non permanente',
#     'taxation_armed_group1': 1,
#     'commerce_taxation_armed_group1': None,
#     'entrance_taxation_armed_group1': None,
#     'monopoly_armed_group1': 0,
#     'buying_minerals_armed_group1': 0,
#     'digging_armed_group1': 0,
#     'forced_labour_armed_group1': 0,
#     'pillaging_armed_group1': None,
#     'armed_group2': 'NDC',
#     'type_armed_group2': 'Groupe armé local',
#     'frequency_armed_group2': 'Non permanente',
#     'taxation_armed_group2': 1,
#     'commerce_taxation_armed_group2': None,
#     'entrance_taxation_armed_group2': None,
#     'monopoly_armed_group2': 0,
#     'buying_minerals_armed_group2': 0,
#     'digging_armed_group2': 0,
#     'forced_labour_armed_group2': 0,
#     'pillaging_armed_group2': None,
#     'state_service1': None,
#     'state_service2': None,
#     'state_service3': None,
#     'state_service4': None,
#     'itsci': None,
#     'traceability': None,
#     'qualification': None,
#     'childunder15': None,
#     'childunder15work': None,
#     'women': None,
#     'womenwork': None}},
#   ...],
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}}

# %% [markdown]
# However, the data is also provided in the tutorial materials as a GeoJSON file, so it is certainly available during the tutorial.

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Read the GeoJSON file `data/cod_mines_curated_all_opendata_p_ipis.geojson` using geopandas, and call the result `data_visits`.</li>
#   <li>Inspect the first 5 rows, and check the number of observations</li>
#  </ul>
#
# </div>

# %%
data_visits = geopandas.read_file("data/cod_mines_curated_all_opendata_p_ipis.geojson")
data_visits.head()
# Out:
#                                                   id  vid  \
# 0  cod_mines_curated_all_opendata_p_ipis.fid-11f0...    1
# 1  cod_mines_curated_all_opendata_p_ipis.fid-11f0...    2
# 2  cod_mines_curated_all_opendata_p_ipis.fid-11f0...    3
# 3  cod_mines_curated_all_opendata_p_ipis.fid-11f0...    4
# 4  cod_mines_curated_all_opendata_p_ipis.fid-11f0...    5
#
#                        source      project         pcode          name  \
# 0  IPIS - Ministère des Mines  IPIS - 2009  codmine00191          Eohe
# 1  IPIS - Ministère des Mines  IPIS - 2009  codmine00192          Eita
# 2  IPIS - Ministère des Mines  IPIS - 2009  codmine00242     Mungu Iko
# 3  IPIS - Ministère des Mines  IPIS - 2009  codmine00260  Kiviri/Tayna
# 4  IPIS - Ministère des Mines  IPIS - 2009  codmine00272       Makanga
#
#    visit_date  visit_onsite visit_onsite_novisitreason  longitude  ...  \
# 0  2009-01-01             1                       None  28.712580  ...
# 1  2009-01-01             1                       None  28.699160  ...
# 2  2009-01-01             1                       None  28.185142  ...
# 3  2009-01-01             1                       None  28.884528  ...
# 4  2009-01-01             1                       None  28.903945  ...
#
#    digging_armed_group2 forced_labour_armed_group2 pillaging_armed_group2  \
# 0                   NaN                        NaN                    NaN
# 1                   NaN                        NaN                    NaN
# 2                   NaN                        NaN                    NaN
# 3                   NaN                        NaN                    NaN
# 4                   NaN                        NaN                    NaN
#
#   state_service1 state_service2 state_service3 state_service4 itsci  \
# 0           None           None           None           None  None
# 1           None           None           None           None  None
# 2           None           None           None           None  None
# 3           None           None           None           None  None
# 4           None           None           None           None  None
#
#    qualification                   geometry
# 0           None   POINT (28.71258 0.33188)
# 1           None   POINT (28.69916 0.32153)
# 2           None   POINT (28.18514 0.54499)
# 3           None  POINT (28.88453 -0.35253)
# 4           None  POINT (28.90395 -0.03671)
#
# [5 rows x 62 columns]

# %% [markdown]
# The provided dataset contains a lot of information, much more than we are going to use in this tutorial. Therefore, we will select a subset of the column:

# %%
data_visits = data_visits[['vid', 'project', 'visit_date', 'name', 'pcode', 'workers_numb', 'interference', 'armed_group1', 'mineral1', 'geometry']]
data_visits.shape
# Out:
# (3687, 10)

# %%
data_visits.head()
# Out:
#    vid      project  visit_date          name         pcode  workers_numb  \
# 0    1  IPIS - 2009  2009-01-01          Eohe  codmine00191         300.0
# 1    2  IPIS - 2009  2009-01-01          Eita  codmine00192         110.0
# 2    3  IPIS - 2009  2009-01-01     Mungu Iko  codmine00242           NaN
# 3    4  IPIS - 2009  2009-01-01  Kiviri/Tayna  codmine00260           NaN
# 4    5  IPIS - 2009  2009-01-01       Makanga  codmine00272           NaN
#
#    interference armed_group1 mineral1                   geometry
# 0           NaN         None       Or   POINT (28.71258 0.33188)
# 1           NaN         None       Or   POINT (28.69916 0.32153)
# 2           NaN        FARDC       Or   POINT (28.18514 0.54499)
# 3           NaN         FDLR       Or  POINT (28.88453 -0.35253)
# 4           NaN         FDLR       Or  POINT (28.90395 -0.03671)

# %% [markdown]
# Before starting the actual geospatial tutorial, we will use some more advanced pandas queries to construct a subset of the data that we will use further on:

# %%
# Take only the data of visits by IPIS
data_ipis = data_visits[data_visits['project'].str.contains('IPIS') & (data_visits['workers_numb'] > 0)]
data_ipis.shape
# Out:
# (2816, 10)

# %%
# For those mining sites that were visited multiple times, take only the last visit
data_ipis_lastvisit = data_ipis.sort_values('visit_date').groupby('pcode', as_index=False).last()
data = geopandas.GeoDataFrame(data_ipis_lastvisit, crs=data_visits.crs)
print(data.shape)
# Out:
# (2151, 10)

# %% [markdown]
# ### Data on protected areas in the same region
#
# Next to the mining site data, we are also going to use a dataset on protected areas (national parks) in Congo. This dataset was downloaded from http://www.wri.org/our-work/project/congo-basin-forests/democratic-republic-congo#project-tabs and included in the tutorial repository: `data/cod_conservation.zip`.

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Extract the `data/cod_conservation.zip` archive, and read the shapefile contained in it. Assign the resulting GeoDataFrame to a variable named `protected_areas`.</li>
#   <li>Quickly plot the GeoDataFrame.</li>
#  </ul>
# </div>

# %%
protected_areas = geopandas.read_file("zip://./data/cod_conservation.zip")
protected_areas.head()
# Out:
#      SCE_SEM    SCE_GEO       DATE_             ORIGINE  \
# 0    WWF/RDC    WWF/RDC  2007-04-18  GPS / Numérisation
# 1  WWF/EARPO  WWF/EARPO  2007-04-18  GPS / Numérisation
# 2     SYGIAP     SYGIAP  2007-04-18  GPS / Numérisation
# 3     SYGIAP     SYGIAP  2007-04-18  GPS / Numérisation
# 4     SYGIAP     SYGIAP  2007-04-18  GPS / Numérisation
#
#                                NOM             REGLEMENT VALID        Statut  \
# 0  Réserve de biosphère de la Luki  Réserve de biosphère   oui          Créé
# 1      Réserve naturelle d'Itombwe     Réserve naturelle   oui          Créé
# 2        Réserve de faune à Okapis     Réserve naturelle   oui  Opérationnel
# 3      Parc National de la Salonga         Parc National   oui  Opérationnel
# 4      Parc National de la Salonga         Parc National   oui  Opérationnel
#
#       Shape_Leng  Categorie  ...        TYPE2_AP                 NAME_AP  \
# 0  133507.042122          0  ...  Nature Reserve  Luki Biosphere Reserve
# 1  726569.150601          0  ...  Nature Reserve  Itombwe Nature Reserve
# 2  699413.460963          0  ...  Nature Reserve    Okapi Faunal Reserve
# 3  994020.751122          0  ...   National park   Salonga National park
# 4  867943.914321          0  ...   National park   Salonga National park
#
#   Ordre OID_ Sup_Admini       Sup_SIG  \
# 0     1    0    32968.0  3.105933e+04
# 1     2    0   605000.0  6.009095e+05
# 2     3    0  1372625.0  1.384674e+06
# 3     0    0  3600000.0  1.704580e+06
# 4     0    0        0.0  1.612007e+06
#
#                                                Texte  Réf_Juridi  \
# 0  C:\Program Files\Atlas RDC 1.0\Documents\Aires...        None
# 1  C:\Program Files\Atlas RDC 1.0\Documents\Aires...        None
# 2  C:\Program Files\Atlas RDC 1.0\Documents\Aires...        None
# 3  C:\Program Files\Atlas RDC 1.0\Documents\Aires...        None
# 4  C:\Program Files\Atlas RDC 1.0\Documents\Aires...        None
#
#                                              Espèces  \
# 0  C:\Program Files\Atlas RDC 1.0\Documents\Aires...
# 1  C:\Program Files\Atlas RDC 1.0\Documents\Aires...
# 2  C:\Program Files\Atlas RDC 1.0\Documents\Aires...
# 3  C:\Program Files\Atlas RDC 1.0\Documents\Aires...
# 4  C:\Program Files\Atlas RDC 1.0\Documents\Aires...
#
#                                             geometry
# 0  POLYGON ((1469015.469 -605537.842, 1469079.666...
# 1  POLYGON ((3132067.854 -408115.011, 3132021.543...
# 2  POLYGON ((3197982.926 148235.506, 3202464.223 ...
# 3  POLYGON ((2384337.186 -280729.974, 2384339.382...
# 4  POLYGON ((2399938.984 -152211.494, 2399998.750...
#
# [5 rows x 28 columns]

# %%
protected_areas.plot()
plt.show()

# %% [markdown]
# ### Conversion to a common Coordinate Reference System
#
# We will see that both datasets use a different Coordinate Reference System (CRS). For many operations, however, it is important that we use a consistent CRS, and therefore we will convert both to a commong CRS.
#
# But first, we explore problems we can encounter related to CRSs.
#
# ---

# %% [markdown]
# [Goma](https://en.wikipedia.org/wiki/Goma) is the capital city of North Kivu province of Congo, close to the border with Rwanda. It's coordinates are 1.66°S 29.22°E.
#
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Create a single Point object representing the location of Goma. Call this `goma`.</li>
#   <li>Calculate the distances of all mines to Goma, and show the 5 smallest distances (mines closest to Goma).</li>
#  </ul>
# </div>

# %%
from shapely.geometry import Point

goma = Point([(29.22,1.66)])
goma

# %%
data['goma_dist'] = data.distance(goma)
data.head()
# Out:
#           pcode  vid                         project  visit_date  \
# 0  codmine00001  657  IPIS - PROMINES MoFA 2013-2014  2013-03-27
# 1  codmine00002  658  IPIS - PROMINES MoFA 2013-2014  2013-03-27
# 2  codmine00003  659  IPIS - PROMINES MoFA 2013-2014  2013-03-27
# 3  codmine00004  660  IPIS - PROMINES MoFA 2013-2014  2013-03-27
# 4  codmine00005  661  IPIS - PROMINES MoFA 2013-2014  2013-03-27
#
#                                  name  workers_numb  interference  \
# 0                           Mayi-Tatu         150.0           1.0
# 1                             Mabanga         115.0           1.0
# 2                             Molende         130.0           1.0
# 3                          Embouchure         135.0           1.0
# 4  Apumu-Atandele-Jerusalem-Luka Yayo         270.0           1.0
#
#   armed_group1 mineral1                  geometry  goma_dist
# 0        FARDC       Or  POINT (29.66033 1.01089)   0.784369
# 1        FARDC       Or  POINT (29.65862 1.00308)   0.789893
# 2        FARDC       Or  POINT (29.65629 0.98563)   0.803196
# 3        FARDC       Or  POINT (29.64494 0.99976)   0.785169
# 4         FRPI       Or  POINT (29.66000 0.95600)   0.830190

# %%
data.sort_values(by="goma_dist",ascending=True).head()
# Out:
#              pcode   vid                  project  visit_date           name  \
# 1905  codmine02681  3035  IPIS - PPA Mambasa 2017  2017-01-24  Bande d'Aouzu
# 1902  codmine02678  3029  IPIS - PPA Mambasa 2017  2017-01-21    Don de Dieu
# 1952  codmine02732  3414  IPIS - PPA Mambasa 2017  2017-06-18        Mondial
# 1954  codmine02734  3402  IPIS - PPA Mambasa 2017  2017-06-15       Bulabula
# 1951  codmine02731  3413  IPIS - PPA Mambasa 2017  2017-06-18        Apemule
#
#       workers_numb  interference armed_group1 mineral1  \
# 1905          25.0           0.0         None       Or
# 1902          13.0           0.0         None       Or
# 1952          14.0           0.0         None       Or
# 1954          19.0           0.0         None       Or
# 1951           2.0           0.0         None       Or
#
#                       geometry  goma_dist
# 1905  POINT (29.13106 1.28992)   0.380617
# 1902  POINT (29.12137 1.29165)   0.381322
# 1952  POINT (29.15736 1.28152)   0.383632
# 1954  POINT (29.12088 1.28238)   0.390409
# 1951  POINT (29.17003 1.27212)   0.391089

# %% [markdown]
# The distances we see here in degrees, which is not helpful for interpreting those distances. That is a reason we will convert the data to another coordinate reference system (CRS) for the remainder of this tutorial.

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Make a visualization of the national parks and the mining sites on a single plot.</li>
#  </ul>
#
# <p>Check the first section of the [04-more-on-visualization.ipynb](04-more-on-visualization.ipynb) notebook for tips and tricks to plot with GeoPandas.</p>
# </div>

# %%
ax = data.plot(color='red') ## mining areas
protected_areas.plot(ax=ax, color="green")
plt.show()

# %% [markdown]
# You will notice that the protected areas and mining sites do not map to the same area on the plot. This is because the Coordinate Reference Systems (CRS) differ for both datasets. Another reason we will need to convert the CRS!
#
# Let's check the Coordinate Reference System (CRS) for both datasets.
#
# The mining sites data uses the [WGS 84 lat/lon (EPSG 4326)](http://spatialreference.org/ref/epsg/4326/) CRS:

# %%
data.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# The protected areas dataset, on the other hand, uses a [WGS 84 / World Mercator (EPSG 3395)](http://spatialreference.org/ref/epsg/wgs-84-world-mercator/) projection (with meters as unit):

# %%
protected_areas.crs
# Out:
# {'proj': 'merc',
#  'lon_0': 0,
#  'lat_ts': 5,
#  'x_0': 0,
#  'y_0': 0,
#  'datum': 'WGS84',
#  'units': 'm',
#  'no_defs': True}

# %% [markdown]
# We will convert both datasets to a local UTM zone, so we can plot them together and that distance-based calculations give sensible results.
#
# To find the appropriate UTM zone, you can check http://www.dmap.co.uk/utmworld.htm or https://www.latlong.net/lat-long-utm.html, and in this case we will use UTM zone 35, which gives use EPSG 32735: https://epsg.io/32735
#
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Convert both datasets (`data` and `protected_areas`) to EPSG 32735. Name the results `data_utm` and `protected_areas_utm`.</li>
#   <li>Try again to visualize both datasets on a single map.</li>
#  </ul>
#
# </div>

# %%
data_utm = data.to_crs(epsg="32735")
protected_areas_utm = protected_areas.to_crs(epsg="32735")
# Out:
# C:\Programdata\Anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Programdata\Anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
countries = geopandas.read_file("zip://./data/ne_110m_admin_0_countries.zip")
countries[countries.name.str.contains("Congo")]
# Out:
#    iso_a3             name continent     pop_est  gdp_md_est  \
# 33    COD  Dem. Rep. Congo    Africa  83301151.0     66010.0
# 34    COG            Congo    Africa   4954674.0     30270.0
#
#                                              geometry
# 33  POLYGON ((23.91222 -10.92683, 23.45679 -10.867...
# 34  POLYGON ((12.99552 -4.78110, 12.62076 -4.43802...

# %%
congo_dr = countries[countries.iso_a3 == "COD"]
congo_dr
# Out:
#    iso_a3             name continent     pop_est  gdp_md_est  \
# 33    COD  Dem. Rep. Congo    Africa  83301151.0     66010.0
#
#                                              geometry
# 33  POLYGON ((23.91222 -10.92683, 23.45679 -10.867...

# %%
congo_dr.crs
# Out:
# {'init': 'epsg:4326'}

# %%
congo_dr_utm = congo_dr.to_crs(epsg=32735)
# Out:
# C:\Programdata\Anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
ax = data_utm.plot(color="red", figsize=(10,10))
protected_areas_utm.plot(ax=ax, color="green")
congo_dr_utm.plot(ax=ax, color="orange", alpha=0.3)
geopandas.GeoSeries(goma, crs="epsg:4326").to_crs(epsg=32735).plot(ax=ax, color="blue")
plt.axis("off")
plt.show()
# Out:
# C:\Programdata\Anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### More advanced visualizations
#
# <p>For the following exercises, check the first section of the [04-more-on-visualization.ipynb](04-more-on-visualization.ipynb) notebook for tips and tricks to plot with GeoPandas.</p>

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Make a visualization of the national parks and the mining sites on a single plot.</li>
#   <li>Pay attention to the following details:
#      <ul>
#       <li>Make the figure a bit bigger.</li>
#       <li>The protected areas should be plotted in green</li>
#       <li>For plotting the mining sites, adjust the markersize and use an `alpha=0.5`.</li>
#       <li>Remove the figure border and x and y labels (coordinates)</li>
#      </ul>
#    </li>
#  </ul>
# </div>

# %%
# %load _solved/solutions/case-conflict-mapping21.py

# %%
# %load _solved/solutions/case-conflict-mapping22.py

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#
#  In addition to the previous figure:
#  <ul>
#   <li>Give the mining sites a distinct color based on the `'interference'` column, indicating whether an armed group is present at the mining site or not.</li>
#  </ul>
# </div>

# %%
ax = data_utm.plot(cmap="jet", column="interference", figsize=(10,10))
protected_areas_utm.plot(ax = ax, color='green')
congo_dr_utm.plot(ax=ax, color="orange", alpha=0.3)
plt.axis("off")
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#
#  In addition to the previous figure:
#  <ul>
#   <li>Give the mining sites a distinct color based on the `'mineral1'` column, indicating which mineral is the primary mined mineral.</li>
#  </ul>
# </div>

# %%
data["mineral1"].value_counts()
# Out:
# Or             1472
# Cassitérite     476
# Coltan          112
# Diamant          46
# Wolframite       33
# Tourmaline        6
# Cuivre            4
# Améthyste         1
# Monazite          1
# Name: mineral1, dtype: int64

# %%
ax = data_utm.plot(cmap="jet", column="mineral1", figsize=(10,10))
protected_areas_utm.plot(ax = ax, color='green')
congo_dr_utm.plot(ax=ax, color="orange", alpha=0.3)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 2. Spatial operations

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#
#  <ul>
#   <li>Access the geometry of the "Kahuzi-Biega National park".</li>
#   <li>Filter the mining sites to select those that are located in this national park.</li>
#  </ul>
# </div>

# %%
# %load _solved/solutions/case-conflict-mapping25.py

# %%
# %load _solved/solutions/case-conflict-mapping26.py

# %%
# %load _solved/solutions/case-conflict-mapping27.py

# %% [markdown]
# <div class="alert alert-success">
#  <b>EXERCISE</b>: Determine for each mining site the "closest" protected area:
#
#  <ul>
#   <li> PART 1 - do this for a single mining site:
#    <ul>
#     <li>Get a single mining site, e.g. the first of the dataset.</li>
#     <li>Calculate the distance (in km's) to all protected areas for this mining site</li>
#     <li>Get the index of the minimum distance (tip: `idxmin()`) and get the name of the protected are corresponding to this index.</li>
#    </ul>
#   </li>
#   <li> PART 2 - apply this procedure on each geometry:
#    <ul>
#     <li>Write the above procedure as a function that gets a single site and the protected areas dataframe as input and returns the name of the closest protected area as output.</li>
#     <li>Apply this function to all sites using the `.apply()` method on `data_utm.geometry`.</li>
#    </ul>
#   </li>
#  </ul>
# </div>

# %%
# %load _solved/solutions/case-conflict-mapping28.py

# %%
# %load _solved/solutions/case-conflict-mapping29.py

# %%
# %load _solved/solutions/case-conflict-mapping30.py

# %%
# %load _solved/solutions/case-conflict-mapping31.py

# %%
# %load _solved/solutions/case-conflict-mapping32.py

# %% [markdown]
# ## 3. Using spatial join to determine mining sites in the protected areas
#
# Based on the analysis and visualizations above, we can already see that there are mining sites inside the protected areas. Let's now do an actual spatial join to determine which sites are within the protected areas.

# %% [markdown]
# ### Mining sites in protected areas
#
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Add information about the protected areas to the mining sites dataset, using a spatial join:
#    <ul>
#     <li>Call the result `data_within_protected`</li>
#     <li>If the result is empty, this is an indication that the coordinate reference system is not matching. Make sure to re-project the data (see above).</li>
#
#    </ul>
#   </li>
#   <li>How many mining sites are located within a national park?</li>
#   <li>Count the number of mining sites per national park (pandas tip: check `value_counts()`)</li>
#
#  </ul>
#
# </div>

# %%
# %load _solved/solutions/case-conflict-mapping33.py

# %%
# %load _solved/solutions/case-conflict-mapping34.py

# %%
# %load _solved/solutions/case-conflict-mapping35.py

# %%
# %load _solved/solutions/case-conflict-mapping36.py

# %% [markdown]
# ### Mining sites in the borders of protected areas
#
# And what about the borders of the protected areas? (just outside the park)
#
# <div class="alert alert-success">
#  <b>EXERCISE</b>:
#  <ul>
#   <li>Create a new dataset, `protected_areas_borders`, that contains the border area (10 km wide) of each protected area:
#    <ul>
#     <li>Tip: one way of doing this is with the `buffer` and `difference` function.</li>
#     <li>Plot the resulting borders as a visual check of correctness.</li>
#    </ul>
#   </li>
#   <li>Count the number of mining sites per national park that are located within its borders</li>
#
#  </ul>
#
# </div>

# %%
# %load _solved/solutions/case-conflict-mapping37.py

# %%
# %load _solved/solutions/case-conflict-mapping38.py

# %%
# %load _solved/solutions/case-conflict-mapping39.py

# %%
# %load _solved/solutions/case-conflict-mapping40.py

# %%
# %load _solved/solutions/case-conflict-mapping41.py
